# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
pd.set_option('display.max_rows', 85)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
df.iloc[[0], [1]]
# Out:
#                        MainBranch
# 0  I am a developer by profession

# %%
df.loc[[1], 'Country']
# Out:
# 1    Netherlands
# Name: Country, dtype: object

# %%
uz_df = df.loc[df['Country'].isin(['Uzbekistan'])]

# %%
uz_df.count
# Out:
# <bound method DataFrame.count of        ResponseId                                         MainBranch  \
# 80             81                     I am a developer by profession
# 307           308             I am a student who is learning to code
# 866           867                     I am a developer by profession
# 1194         1195                     I am a developer by profession
# 4675         4676             I am a student who is learning to code
# 5353         5354                     I am a developer by profession
# 7997         7998                     I am a developer by profession
# 9601         9602                     I am a developer by profession
# 12650       12651                     I am a developer by profession
# 12753       12754                     I am a developer by profession
# 13684       13685                     I am a developer by profession
# 14326       14327                     I am a developer by profession
# ...

# %%
uz_df['MainBranch']
# Out:
# 80                          I am a developer by profession
# 307                 I am a student who is learning to code
# 866                         I am a developer by profession
# 1194                        I am a developer by profession
# 4675                I am a student who is learning to code
# 5353                        I am a developer by profession
# 7997                        I am a developer by profession
# 9601                        I am a developer by profession
# 12650                       I am a developer by profession
# 12753                       I am a developer by profession
# 13684                       I am a developer by profession
# 14326                       I am a developer by profession
# 14725                       I am a developer by profession
# 15175                       I am a developer by profession
# 16277                       I am a developer by profession
# 19570                       I am a developer by profession
# ...

# %%
uz_df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53
# I am a student who is learning to code                                           12
# I am not primarily a developer, but I write code sometimes as part of my work     3
# Name: MainBranch, dtype: int64

# %%
type(uz_df['MainBranch'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df.loc[1:3, 'MainBranch']
# Out:
# 1               I am a student who is learning to code
# 2    I am not primarily a developer, but I write co...
# 3                       I am a developer by profession
# Name: MainBranch, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
uz_df.loc[80:10000, 'Sexuality'].value_counts()
# Out:
# Straight / Heterosexual    5
# Prefer not to say          2
# Name: Sexuality, dtype: int64

# %%
df.set_index('Country', inplace=True)

# %%
t = df.loc[['Uzbekistan'], 'ResponseId':'YearsCode'].unstack()

# %%
t
# Out:
#             Country
# ResponseId  Uzbekistan                  81
#             Uzbekistan                 308
#             Uzbekistan                 867
#             Uzbekistan                1195
#             Uzbekistan                4676
#                                 ...
# YearsCode   Uzbekistan    Less than 1 year
#             Uzbekistan                   7
#             Uzbekistan                   4
#             Uzbekistan                   5
#             Uzbekistan                   2
# Length: 612, dtype: object

# %%
df.sort_index(inplace=True)

# %%
df.loc['Uzbekistan'].values
# Out:
# array([[19571, 'I am a developer by profession', 'Employed full-time',
#         ..., 'Appropriate in length', 'Easy', 25200.0],
#        [37682, 'I am a developer by profession', 'Employed full-time',
#         ..., nan, 'Neither easy nor difficult', 18000.0],
#        [39960, 'I am a developer by profession', 'Employed full-time',
#         ..., 'Appropriate in length', 'Easy', 4800.0],
#        ...,
#        [48481, 'I am a developer by profession', 'Employed full-time',
#         ..., 'Appropriate in length', 'Easy', nan],
#        [31747, 'I am a developer by profession', 'Employed full-time',
#         ..., 'Appropriate in length', 'Neither easy nor difficult', nan],
#        [33545, 'I am a developer by profession', 'Employed full-time',
#         ..., 'Appropriate in length', 'Easy', 48000.0]], dtype=object)
